# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuyas/TimeSeriesEntropy/blob/master/TimeSeries_WhiteNoisePlots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tabulate import tabulate
import pandas as pd
import time as time
import seaborn as sns
import pickle
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def save_obj(obj, name ):
    with open('/content/drive/My Drive/TimeSeries/save/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('/content/drive/My Drive/TimeSeries/save/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# # White Noise

# %%
wn_10_1000_MSE = load_obj("white_noise_10_1000_MSE")
wn_10_1000_CV_MSE = load_obj("white_noise_10_1000_CV_MSE")
wn_10_1000_CMSE = load_obj("white_noise_10_1000_CMSE")
wn_10_1000_CV_CMSE = load_obj("white_noise_10_1000_CV_CMSE")
wn_10_1000_FMSE = load_obj("white_noise_10_1000_FMSE")
wn_10_1000_CV_FMSE = load_obj("white_noise_10_1000_CV_FMSE")

wn_10_2000_MSE = load_obj("white_noise_10_2000_MSE")
wn_10_2000_CV_MSE = load_obj("white_noise_10_2000_CV_MSE")
wn_10_2000_CMSE = load_obj("white_noise_10_2000_CMSE")
wn_10_2000_CV_CMSE = load_obj("white_noise_10_2000_CV_CMSE")
wn_10_2000_FMSE = load_obj("white_noise_10_2000_FMSE")
wn_10_2000_CV_FMSE = load_obj("white_noise_10_2000_CV_FMSE")

wn_10_10000_MSE = load_obj("white_noise_10_10000_MSE")
wn_10_10000_CV_MSE = load_obj("white_noise_10_10000_CV_MSE")
wn_10_10000_CMSE = load_obj("white_noise_10_10000_CMSE")
wn_10_10000_CV_CMSE = load_obj("white_noise_10_10000_CV_CMSE")
wn_10_10000_FMSE = load_obj("white_noise_10_10000_FMSE")
wn_10_10000_CV_FMSE = load_obj("white_noise_10_10000_CV_FMSE")

wn_100_1000_MSE = load_obj("white_noise_10_1000_MSE")
wn_100_1000_CV_MSE = load_obj("white_noise_10_1000_CV_MSE")
wn_100_1000_CMSE = load_obj("white_noise_10_1000_CMSE")
wn_100_1000_CV_CMSE = load_obj("white_noise_10_1000_CV_CMSE")
wn_100_1000_FMSE = load_obj("white_noise_10_1000_FMSE")
wn_100_1000_CV_FMSE = load_obj("white_noise_10_1000_CV_FMSE")

wn_100_2000_MSE = load_obj("white_noise_10_2000_MSE")
wn_100_2000_CV_MSE = load_obj("white_noise_10_2000_CV_MSE")
wn_100_2000_CMSE = load_obj("white_noise_10_2000_CMSE")
wn_100_2000_CV_CMSE = load_obj("white_noise_10_2000_CV_CMSE")
wn_100_2000_FMSE = load_obj("white_noise_10_2000_FMSE")
wn_100_2000_CV_FMSE = load_obj("white_noise_10_2000_CV_FMSE")

wn_100_10000_MSE = load_obj("white_noise_10_10000_MSE")
wn_100_10000_CV_MSE = load_obj("white_noise_10_10000_CV_MSE")
wn_100_10000_CMSE = load_obj("white_noise_10_10000_CMSE")
wn_100_10000_CV_CMSE = load_obj("white_noise_10_10000_CV_CMSE")
wn_100_10000_FMSE = load_obj("white_noise_10_10000_FMSE")
wn_100_10000_CV_FMSE = load_obj("white_noise_10_10000_CV_FMSE")

# %%
# WHITE NOISE SIGNALS=10, N=1000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_MSE), "b-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_CMSE), "r-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_FMSE), "g-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_CV_MSE), "b-x")
axes.plot((wn_10_1000_CV_CMSE), "r-x")
axes.plot((wn_10_1000_CV_FMSE), "g-x")

axes.set_xlabel("Scale Factor")
axes.set_ylabel("CV")
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
# WHITE NOISE SIGNALS=10, N=2000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_2000_MSE), "b-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_2000_CMSE), "r-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_2000_FMSE), "g-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_2000_CV_MSE), "b-x")
axes.plot((wn_10_2000_CV_CMSE), "r-x")
axes.plot((wn_10_2000_CV_FMSE), "g-x")

axes.set_xlabel("Scale Factor")
axes.set_ylabel("CV")
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
# WHITE NOISE SIGNALS=10, N=10000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_10000_MSE), "b-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_10000_CMSE), "r-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_10000_FMSE), "g-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_10000_CV_MSE), "b-x")
axes.plot((wn_10_10000_CV_CMSE), "r-x")
axes.plot((wn_10_10000_CV_FMSE), "g-x")

axes.set_xlabel("Scale Factor")
axes.set_ylabel("CV")
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
# WHITE NOISE SIGNALS=100, N=1000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_1000_MSE), "b-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_1000_CMSE), "r-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_1000_FMSE), "g-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_1000_CV_MSE), "b-x")
axes.plot((wn_100_1000_CV_CMSE), "r-x")
axes.plot((wn_100_1000_CV_FMSE), "g-x")

axes.set_xlabel("Scale Factor")
axes.set_ylabel("CV")
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
# WHITE NOISE SIGNALS=100, N=2000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_2000_MSE), "b-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_2000_CMSE), "r-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_2000_FMSE), "g-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_2000_CV_MSE), "b-x")
axes.plot((wn_100_2000_CV_CMSE), "r-x")
axes.plot((wn_100_2000_CV_FMSE), "g-x")

axes.set_xlabel("Scale Factor")
axes.set_ylabel("CV")
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
# WHITE NOISE SIGNALS=100, N=10000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_10000_MSE), "b-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_10000_CMSE), "r-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_10000_FMSE), "g-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_100_10000_CV_MSE), "b-x")
axes.plot((wn_100_10000_CV_CMSE), "r-x")
axes.plot((wn_100_10000_CV_FMSE), "g-x")

axes.set_xlabel("Scale Factor")
axes.set_ylabel("CV")
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
# WHITE NOISE SIGNALS=10, N=1000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_MSE), "r-x")
axes.plot((wn_10_2000_MSE), "g-x")
axes.plot((wn_10_10000_MSE), "b-x")
axes.plot((wn_100_1000_MSE), "c-x")
axes.plot((wn_100_2000_MSE), "m-x")
axes.plot((wn_100_10000_MSE), "y-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_CMSE), "r-x")
axes.plot((wn_10_2000_CMSE), "g-x")
axes.plot((wn_10_10000_CMSE), "b-x")
axes.plot((wn_100_1000_CMSE), "c-x")
axes.plot((wn_100_2000_CMSE), "m-x")
axes.plot((wn_100_10000_CMSE), "y-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_FMSE), "r-x")
axes.plot((wn_10_2000_FMSE), "g-x")
axes.plot((wn_10_10000_FMSE), "b-x")
axes.plot((wn_100_1000_FMSE), "c-x")
axes.plot((wn_100_2000_FMSE), "m-x")
axes.plot((wn_100_10000_FMSE), "y-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
plt.xlim(0)
plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((wn_10_1000_CV_MSE), "b-x")
axes.plot((wn_10_1000_CV_CMSE), "r-x")
axes.plot((wn_10_1000_CV_FMSE), "g-x")
axes.plot((wn_10_2000_CV_MSE), "b-x")
axes.plot((wn_10_2000_CV_CMSE), "r-x")
axes.plot((wn_10_2000_CV_FMSE), "g-x")
axes.plot((wn_10_10000_CV_MSE), "b-x")
axes.plot((wn_10_10000_CV_CMSE), "r-x")
axes.plot((wn_10_10000_CV_FMSE), "g-x")

axes.plot((wn_100_1000_CV_MSE), "c-x")
axes.plot((wn_100_1000_CV_CMSE), "m-x")
axes.plot((wn_100_1000_CV_FMSE), "y-x")
axes.plot((wn_100_2000_CV_MSE), "c-x")
axes.plot((wn_100_2000_CV_CMSE), "m-x")
axes.plot((wn_100_2000_CV_FMSE), "y-x")
axes.plot((wn_100_10000_CV_MSE), "c-x")
axes.plot((wn_100_10000_CV_CMSE), "m-x")
axes.plot((wn_100_10000_CV_FMSE), "y-x")

axes.set_xlabel("Scale Factor")
axes.set_ylabel("CV")
plt.xlim(0)
plt.ylim(0)
plt.show()

# %% [markdown]
# # PM 2.5

# %% [markdown]
# ## Aotizhongxin

# %%
Ao_PM25_MSE = load_obj("Aotizhongxin_PM2.51_35064_MSE")
Ao_PM25_CV_MSE = load_obj("Aotizhongxin_PM2.51_35064_CV_MSE")
Ao_PM25_CMSE = load_obj("Aotizhongxin_PM2.51_35064_CMSE")
Ao_PM25_CV_CMSE = load_obj("Aotizhongxin_PM2.51_35064_CV_CMSE")
Ao_PM25_FMSE = load_obj("Aotizhongxin_PM2.51_35064_FMSE")
Ao_PM25_CV_FMSE = load_obj("Aotizhongxin_PM2.51_35064_CV_FMSE")

# %%
# WHITE NOISE SIGNALS=10, N=1000
fig, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((Ao_PM25_MSE), "b-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("MSE")
# plt.xlim(0)
# plt.ylim(0)
plt.show()

fig1, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((Ao_PM25_CMSE), "r-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("CMSE")
# axes.set_xlim(-1.5)
# axes.set_ylim(-1.5,2)
plt.show()

fig2, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((Ao_PM25_FMSE), "g-x")
axes.set_xlabel("Scale Factor")
axes.set_ylabel("FMSE")
# plt.xlim(0)
# plt.ylim(0)
plt.show()

fig3, axes = plt.subplots(nrows=1, ncols=1,figsize=(10,5))
axes.plot((Ao_PM25_CV_MSE), "b-x")
axes.plot((Ao_PM25_CV_CMSE), "r-x")
axes.plot((Ao_PM25_CV_FMSE), "g-x")
axes.set_ylabel("CV")
axes.set_xlabel("Scale Factor")
plt.show()
